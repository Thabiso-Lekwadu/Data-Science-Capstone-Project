# %%
import pandas as pd
import numpy as np
import seaborn as sns
from dotenv import load_dotenv
import os

import warnings
warnings.filterwarnings("ignore")

# %%
load_dotenv('.env')
# Out:
# True

# %%
api_key = os.getenv("EASYDATA_API_KEY")
api_url = os.getenv("EASYDATA_API_URL")

# %%
from quantec.easydata.client import Client
# All parameters and defaults
client = Client(
    api_key= api_key,  # default: uses EASYDATA_API_KEY env var
    api_url= api_url,  # default: EASYDATA_API_URL or "https://www.easydata.co.za/api/v3"
    use_cache=True,
    cache_dir="cache",
)

# %%
pk = """
SAPS-E_P9-S_LIC01S00-C_T
SAPS-E_P9-S_LIC01S00-C_S
SAPS-E_P9-S_LIC01S00-C_SR
SAPS-E_P9-S_LIC01S00-C_SRC
SAPS-E_P9-S_LIC01S00-C_SRCM
SAPS-E_P9-S_LIC01S00-C_SRCS
SAPS-E_P9-S_LIC01S00-C_SRCSQ
SAPS-E_P9-S_LIC01S00-C_SRCSC
SAPS-E_P9-S_LIC01S00-C_SRCSB
SAPS-E_P9-S_LIC01S00-C_SRCSR
SAPS-E_P9-S_LIC01S00-C_SRCSA
SAPS-E_P9-S_LIC01S00-C_SRCSD
SAPS-E_P9-S_LIC01S00-C_SRCSI
SAPS-E_P9-S_LIC01S00-C_SRCSS
SAPS-E_P9-S_LIC01S00-C_SRCL
SAPS-E_P9-S_LIC01S00-C_SRCH
SAPS-E_P9-S_LIC01S00-C_SRCA
SAPS-E_P9-S_LIC01S00-C_SRCR
SAPS-E_P9-S_LIC01S00-C_SRCX
SAPS-E_P9-S_LIC01S00-C_SRCXS
SAPS-E_P9-S_LIC01S00-C_SRCXR
SAPS-E_P9-S_LIC01S00-C_SRCXB
SAPS-E_P9-S_LIC01S00-C_SRCXC
SAPS-E_P9-S_LIC01S00-C_SRCXO
SAPS-E_P9-S_LIC01S00-C_SRCX3
SAPS-E_P9-S_LIC01S00-C_SRCX3B
SAPS-E_P9-S_LIC01S00-C_SRCX3R
SAPS-E_P9-S_LIC01S00-C_SRCX3C
SAPS-E_P9-S_LIC01S00-C_SRCXT
SAPS-E_P9-S_LIC01S00-C_SRR
SAPS-E_P9-S_LIC01S00-C_SRRA
SAPS-E_P9-S_LIC01S00-C_SRRP
SAPS-E_P9-S_LIC01S00-C_SRP
SAPS-E_P9-S_LIC01S00-C_SRPR
SAPS-E_P9-S_LIC01S00-C_SRPB
SAPS-E_P9-S_LIC01S00-C_SRPV
SAPS-E_P9-S_LIC01S00-C_SRPF
SAPS-E_P9-S_LIC01S00-C_SRPS
SAPS-E_P9-S_LIC01S00-C_SRO
SAPS-E_P9-S_LIC01S00-C_SROO
SAPS-E_P9-S_LIC01S00-C_SROC
SAPS-E_P9-S_LIC01S00-C_SROS
SAPS-E_P9-S_LIC01S00-C_SD
SAPS-E_P9-S_LIC01S00-C_SDF
SAPS-E_P9-S_LIC01S00-C_SDN
SAPS-E_P9-S_LIC01S00-C_SDD
SAPS-E_P9-S_LIC01S00-C_SDS
SAPS-E_P9-S_LIC04S00-C_SRCS
SAPS-E_P9-S_LIC04S00-C_SRCSQ
SAPS-E_P9-S_LIC04S00-C_SRCSC
SAPS-E_P9-S_LIC04S00-C_SRCSB
SAPS-E_P9-S_LIC04S00-C_SRCSR
SAPS-E_P9-S_LIC04S00-C_SRCSA
SAPS-E_P9-S_LIC04S00-C_SRCSD
SAPS-E_P9-S_LIC04S00-C_SRCSI
SAPS-E_P9-S_LIC04S00-C_SRCSS
SAPS-E_P9-S_LIC04S00-C_SRCL
SAPS-E_P9-S_LIC04S00-C_SRCH
SAPS-E_P9-S_LIC04S00-C_SRCA
SAPS-E_P9-S_LIC04S00-C_SRCR
SAPS-E_P9-S_LIC04S00-C_SRCX
SAPS-E_P9-S_LIC04S00-C_SRCXS
SAPS-E_P9-S_LIC04S00-C_SRCXR
SAPS-E_P9-S_LIC04S00-C_SRCXB
SAPS-E_P9-S_LIC04S00-C_SRCXC
SAPS-E_P9-S_LIC04S00-C_SRCXO
SAPS-E_P9-S_LIC04S00-C_SRCX3
SAPS-E_P9-S_LIC04S00-C_SRCX3B
SAPS-E_P9-S_LIC04S00-C_SRCX3R
SAPS-E_P9-S_LIC04S00-C_SRCX3C
SAPS-E_P9-S_LIC04S00-C_SRCXT
SAPS-E_P9-S_LIC04S00-C_SRR
SAPS-E_P9-S_LIC04S00-C_SRRA
SAPS-E_P9-S_LIC04S00-C_SRRP
SAPS-E_P9-S_LIC04S00-C_SRP
SAPS-E_P9-S_LIC04S00-C_SRPR
SAPS-E_P9-S_LIC04S00-C_SRPB
SAPS-E_P9-S_LIC04S00-C_SRPV
SAPS-E_P9-S_LIC04S00-C_SRPF
SAPS-E_P9-S_LIC04S00-C_SRPS
SAPS-E_P9-S_LIC04S00-C_SRO
SAPS-E_P9-S_LIC04S00-C_SROO
SAPS-E_P9-S_LIC04S00-C_SROC
SAPS-E_P9-S_LIC04S00-C_SROS
SAPS-E_P9-S_LIC04S00-C_SD
SAPS-E_P9-S_LIC04S00-C_SDF
SAPS-E_P9-S_LIC04S00-C_SDN
SAPS-E_P9-S_LIC04S00-C_SDD
SAPS-E_P9-S_LIC04S00-C_SDS
SAPS-E_P9-S_LIC04S00-C_O
SAPS-E_P9-S_LIC04S00-C_OH
SAPS-E_P9-S_LIC04S00-C_OV
SAPS-E_P9-S_LIC04S00-C_OC
SAPS-E_P9-S_LIC04S00-C_ON
SAPS-E_P9-S_LIC04S00-C_OK
"""

# %%
# Get time series data (CSV format only)
data = client.get_data(time_series_codes=pk)
data.head()
# Out:
#                                                title  \
# 0  P9: Limpopo — LIC01S00: Bela Bela Cluster — T:...
# 1  P9: Limpopo — LIC01S00: Bela Bela Cluster — T:...
# 2  P9: Limpopo — LIC01S00: Bela Bela Cluster — T:...
# 3  P9: Limpopo — LIC01S00: Bela Bela Cluster — T:...
# 4  P9: Limpopo — LIC01S00: Bela Bela Cluster — T:...
#
#                                                 unit  \
# 0  Number of recorded crimes (custom of Monthly V...
# 1  Number of recorded crimes (custom of Monthly V...
# 2  Number of recorded crimes (custom of Monthly V...
# 3  Number of recorded crimes (custom of Monthly V...
# 4  Number of recorded crimes (custom of Monthly V...
#
#                                   source                          code  \
# 0  South African Police Service; Quantec  SAPS-E_P9-S_LIC01S00-C_T-CAN
# 1  South African Police Service; Quantec  SAPS-E_P9-S_LIC01S00-C_T-CAN
# 2  South African Police Service; Quantec  SAPS-E_P9-S_LIC01S00-C_T-CAN
# ...

# %%
data.tail()
# Out:
#                                                   title  \
# 1585  P9: Limpopo — LIC01S00: Bela Bela Cluster — OK...
# 1586  P9: Limpopo — LIC01S00: Bela Bela Cluster — OK...
# 1587  P9: Limpopo — LIC01S00: Bela Bela Cluster — OK...
# 1588  P9: Limpopo — LIC01S00: Bela Bela Cluster — OK...
# 1589  P9: Limpopo — LIC01S00: Bela Bela Cluster — OK...
#
#                                                    unit  \
# 1585  Number of recorded crimes (custom of Monthly V...
# 1586  Number of recorded crimes (custom of Monthly V...
# 1587  Number of recorded crimes (custom of Monthly V...
# 1588  Number of recorded crimes (custom of Monthly V...
# 1589  Number of recorded crimes (custom of Monthly V...
#
#                                      source                           code  \
# 1585  South African Police Service; Quantec  SAPS-E_P9-S_LIC01S00-C_OK-CAN
# 1586  South African Police Service; Quantec  SAPS-E_P9-S_LIC01S00-C_OK-CAN
# ...

# %%
data["date"] = pd.to_datetime(data["date"])

# %%
import numpy as np
data["value"] = np.floor(data['value']).astype('Int64')

# %%
data["date"].unique()
# Out:
# <DatetimeArray>
# ['1995-12-31 00:00:00', '1996-12-31 00:00:00', '1997-12-31 00:00:00',
#  '1998-12-31 00:00:00', '1999-12-31 00:00:00', '2000-12-31 00:00:00',
#  '2001-12-31 00:00:00', '2002-12-31 00:00:00', '2003-12-31 00:00:00',
#  '2004-12-31 00:00:00', '2005-12-31 00:00:00', '2006-12-31 00:00:00',
#  '2007-12-31 00:00:00', '2008-12-31 00:00:00', '2009-12-31 00:00:00',
#  '2010-12-31 00:00:00', '2011-12-31 00:00:00', '2012-12-31 00:00:00',
#  '2013-12-31 00:00:00', '2014-12-31 00:00:00', '2015-12-31 00:00:00',
#  '2016-12-31 00:00:00', '2017-12-31 00:00:00', '2018-12-31 00:00:00',
#  '2019-12-31 00:00:00', '2020-12-31 00:00:00', '2021-12-31 00:00:00',
#  '2022-12-31 00:00:00', '2023-12-31 00:00:00', '2024-12-31 00:00:00']
# Length: 30, dtype: datetime64[ns]

# %%
data.shape
# Out:
# (1590, 6)

# %%
data.tail()
# Out:
#                                                   title  \
# 1585  P9: Limpopo — LIC01S00: Bela Bela Cluster — OK...
# 1586  P9: Limpopo — LIC01S00: Bela Bela Cluster — OK...
# 1587  P9: Limpopo — LIC01S00: Bela Bela Cluster — OK...
# 1588  P9: Limpopo — LIC01S00: Bela Bela Cluster — OK...
# 1589  P9: Limpopo — LIC01S00: Bela Bela Cluster — OK...
#
#                                                    unit  \
# 1585  Number of recorded crimes (custom of Monthly V...
# 1586  Number of recorded crimes (custom of Monthly V...
# 1587  Number of recorded crimes (custom of Monthly V...
# 1588  Number of recorded crimes (custom of Monthly V...
# 1589  Number of recorded crimes (custom of Monthly V...
#
#                                      source                           code  \
# 1585  South African Police Service; Quantec  SAPS-E_P9-S_LIC01S00-C_OK-CAN
# 1586  South African Police Service; Quantec  SAPS-E_P9-S_LIC01S00-C_OK-CAN
# ...

# %% [markdown]
# * Read in Datasets

# %%
df1 = pd.read_excel("C:/Users/amare/OneDrive/Desktop/Pycharm practice/datasets/1st Batch.xlsx", sheet_name="Monthly")
df2 = pd.read_excel("C:/Users/amare/OneDrive/Desktop/Pycharm practice/datasets/2nd Batch.xlsx", sheet_name="Monthly")
df3 = pd.read_excel("C:/Users/amare/OneDrive/Desktop/Pycharm practice/datasets/3rd Batch.xlsx", sheet_name="Monthly")

# %%
def preprocess(df):
    df = df[4:]
    df = df.drop(range(5, 8))
    df.columns = df.iloc[0]
    df = df.iloc[1:]
    df = df.rename(columns={'title': 'Date'})
    df = df.set_index("Date")
    df.index = pd.to_datetime(df.index)

    return df

# %%
df1 = preprocess(df1)
df2 = preprocess(df2)
df3 = preprocess(df3)

# %%
def impute_missing(df):
        df = df.fillna(0)
        df = df.round(0).astype('Int64')
        return df

# %%
df1 = impute_missing(df1)
df2 = impute_missing(df2)
df3 = impute_missing(df3)

# %% [markdown]
# Impute missing values

# %%
df3
# Out:
# 4           P9: Limpopo — LIC10S00: Modimolle Cluster — T: 25 Serious and Other crimes  \
# Date
# 2001-01-31                                                453
# 2001-02-28                                                460
# 2001-03-31                                                537
# 2001-04-30                                                479
# 2001-05-31                                                464
# ...                                                       ...
# 2025-05-31                                                277
# 2025-06-30                                                272
# 2025-07-31                                                279
# 2025-08-31                                                310
# 2025-09-30                                                264
#
# 4           P9: Limpopo — LIC10S00: Modimolle Cluster — S: 20 Serious crimes  \
# Date
# 2001-01-31                                                421
# ...

# %%
data = df1.merge(df2, left_index=True, right_index=True, how='outer').merge(df3, left_index=True, right_index=True, how='outer')

# %%
# Out:
# Index([2001, 2001, 2001, 2001, 2001, 2001, 2001, 2001, 2001, 2001,
#        ...
#        2024, 2025, 2025, 2025, 2025, 2025, 2025, 2025, 2025, 2025],
#       dtype='int32', name='Date', length=297)

# %%
data['Year'] = data.index.year
data
# Out:
# 4           P9: Limpopo — LIC01S00: Bela Bela Cluster — T: 25 Serious and Other crimes  \
# Date
# 2001-01-31                                                567
# 2001-02-28                                                472
# 2001-03-31                                                593
# 2001-04-30                                                540
# 2001-05-31                                                519
# ...                                                       ...
# 2025-05-31                                                455
# 2025-06-30                                                418
# 2025-07-31                                                431
# 2025-08-31                                                523
# 2025-09-30                                                447
#
# 4           P9: Limpopo — LIC01S00: Bela Bela Cluster — S: 20 Serious crimes  \
# Date
# 2001-01-31                                                532
# ...

# %% [markdown]
# Concat/ Join 1st, 2nd and 3rd batch on index. make date the index
